# %% [markdown]
# # Screenshot Baseline
#
# This notebook documents the professor-safe legacy baseline path: short synthetic biomedical text plus a simple TF-IDF + LogisticRegression detector.

# %%
import os
os.environ['PYTHONPATH'] = 'src'
# !python3 -m biofake.cli pipeline run --config configs/experiments/screenshot_baseline.yaml
